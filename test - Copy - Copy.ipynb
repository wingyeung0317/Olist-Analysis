# %%
import pandas as pd
import numpy as np
dataset = pd.read_csv("E:/JDE/olist/olist_order_reviews_dataset.csv")

# %%
from textblob import TextBlob

# %%
def translating(comment):
    try:
        translated_comment = TextBlob(comment).translate(from_lang='pt-BR', to='en')
    except:
        translated_comment = comment
    return translated_comment

# %%
dataset['translate_comment_message'] = dataset['review_comment_message'].apply(lambda x: translating(x))

# for i, comment in enumerate(dataset['review_comment_message']):
#     try:
#         translated_comment = TextBlob(comment).translate(from_lang='pt-BR', to='en')
#     except:
#         translated_comment = comment
#     dataset.loc[i, 'translate_comment_message'] = str(translated_comment)
    # if i == 7:
    #     break

# %%
dataset.loc[:7]
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 5  15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6  07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# 7  7c6400515c67679fbee952a7525281ef  c31a859e34e3adac22f376954e19b39d
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
# 5             1                  NaN
# 6             5                  NaN
# ...
